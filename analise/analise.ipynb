# %%
import pandas as pd

# %%
clientes=pd.read_csv(r"C:\Users\didio\OneDrive\Documentos\analises\online-retail-analysis\datas\olist_customers_dataset.csv")

# %%
clientes.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# excluindo colunas desnecessarias

# %%
clientes=clientes.drop(columns=["customer_unique_id","customer_zip_code_prefix"])

# %%
clientes
# Out:
#                             customer_id          customer_city customer_state
# 0      06b8999e2fba1a1fbc88172c00ba8bc7                 franca             SP
# 1      18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo             SP
# 2      4e7b3e00288586ebd08712fdd0374a03              sao paulo             SP
# 3      b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes             SP
# 4      4f2d8ab171c80ec8364f7c12e35b23ad               campinas             SP
# ...                                 ...                    ...            ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f              sao paulo             SP
# 99437  e7b71a9017aa05c9a7fd292d714858e8        taboao da serra             SP
# 99438  5e28dfe12db7fb50a4b2f691faecea5e              fortaleza             CE
# 99439  56b18e2166679b8a959d72dd06da27f9                 canoas             RS
# 99440  274fa6071e5e17fe303b9748641082c8                  cotia             SP
#
# [99441 rows x 3 columns]

# %%
clientes.isnull()
# Out:
#        customer_id  customer_city  customer_state
# 0            False          False           False
# 1            False          False           False
# 2            False          False           False
# 3            False          False           False
# 4            False          False           False
# ...            ...            ...             ...
# 99436        False          False           False
# 99437        False          False           False
# 99438        False          False           False
# 99439        False          False           False
# 99440        False          False           False
#
# [99441 rows x 3 columns]

# %%
pedidos=pd.read_csv(r"C:\Users\didio\OneDrive\Documentos\analises\online-retail-analysis\datas\olist_orders_dataset.csv")

# %%
pedidos
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
pedidos=pedidos.drop(columns=["order_purchase_timestamp","order_approved_at","order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date"])

# %%
pedidos
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status
# 0        delivered
# 1        delivered
# ...

# %%
juntos=pd.merge(clientes,pedidos,on="customer_id",how="inner")

# %%
juntos.isnull(
    
)
# Out:
#        customer_id  customer_city  customer_state  order_id  order_status
# 0            False          False           False     False         False
# 1            False          False           False     False         False
# 2            False          False           False     False         False
# 3            False          False           False     False         False
# 4            False          False           False     False         False
# ...            ...            ...             ...       ...           ...
# 99436        False          False           False     False         False
# 99437        False          False           False     False         False
# 99438        False          False           False     False         False
# 99439        False          False           False     False         False
# 99440        False          False           False     False         False
#
# [99441 rows x 5 columns]

# %%
juntos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     99441 non-null  object
#  1   customer_city   99441 non-null  object
#  2   customer_state  99441 non-null  object
#  3   order_id        99441 non-null  object
#  4   order_status    99441 non-null  object
# dtypes: object(5)
# memory usage: 3.8+ MB

# %%
juntos.isnull
# Out:
# <bound method DataFrame.isnull of                             customer_id          customer_city customer_state  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7                 franca             SP
# 1      18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo             SP
# 2      4e7b3e00288586ebd08712fdd0374a03              sao paulo             SP
# 3      b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes             SP
# 4      4f2d8ab171c80ec8364f7c12e35b23ad               campinas             SP
# ...                                 ...                    ...            ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f              sao paulo             SP
# 99437  e7b71a9017aa05c9a7fd292d714858e8        taboao da serra             SP
# 99438  5e28dfe12db7fb50a4b2f691faecea5e              fortaleza             CE
# 99439  56b18e2166679b8a959d72dd06da27f9                 canoas             RS
# 99440  274fa6071e5e17fe303b9748641082c8                  cotia             SP
#
# ...

# %%
juntos.isnull().sum().value_counts()
# Out:
# 0    5
# Name: count, dtype: int64

# %%
juntos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 juntos
#
# NameError: name 'juntos' is not defined

# %%
pedidos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pedidos
#
# NameError: name 'pedidos' is not defined

# %%
pedidos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pedidos
#
# NameError: name 'pedidos' is not defined
